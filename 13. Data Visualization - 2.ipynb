# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(y='tip',data=ims)  #Single variable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1632/1656528314.py in <module>
# ----> 1 sns.boxplot(y='tip',data=ims)  #Single variable
#
# NameError: name 'ims' is not defined

# %%
sns.boxplot(data=ims)  #For all number variables

# %%
sns.boxplot(x='day',y="total_bill",data=ims)

# %%
sns.boxplot(x='day',y="total_bill",hue='sex', data=ims, palette='set1')

# %% [markdown]
# # Pie Charts

# %%
ims.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1632/1629097026.py in <module>
# ----> 1 ims.head()
#
# NameError: name 'ims' is not defined

# %%
#Group by data delivery types
data=ims.groupby("day")["total_bill"].sum()
data

# %%
data.plot.pie(autopct="%.1f%%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1632/1243695815.py in <module>
# ----> 1 data.plot.pie(autopct="%.1f%%")
#
# NameError: name 'data' is not defined

# %% [markdown]
# # Line Charts

# %%
flights=sns.load_dataset("flights")
flights.head()

# %%
sns.lineplot(data=flights, x="year", y="passengers")

# %%
sns.lineplot(data=flights, x="year", y="passengers",hue="month")   #hue use to break

# %%
sns.lineplot(data=flights, x="year", y="passengers",hue="month", style="month")

# %%
fmri=sns.load_dataset("fmri")
fmri.head()

# %%
sns.lineplot(data=fmri, x="timepoint",y="single",hue="event")

# %%
sns.lineplot(
    data=fmri
    x="timepoint", y="signal",hue="event",style="event",
    markers=True,dashes=False
)

# %%
sns.replot(
    data=fmri
    x="timepoint", y="signal", col ="region", hue="event",style="event",
    kinds="line"
)

# %% [markdown]
# # Funnel Charts

# %%
grp=abc.groupby("day",as_index=False).agg({'total_bill':'sum'}).sort_values(by='total_bill',ascending=False)
grp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1632/1509882860.py in <module>
# ----> 1 grp=abc.groupby("day",as_index=False).agg({'total_bill':'sum'}).sort_values(by='total_bill',ascending=False)
#       2 grp
#
# NameError: name 'abc' is not defined

# %%
fig=px.funnel(grp, x='total_bill', y='day')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1632/105227914.py in <module>
# ----> 1 fig=px.funnel(grp, x='total_bill', y='day')
#       2 fig.show()
#
# NameError: name 'px' is not defined

# %% [markdown]
# # Bubble Charts

# %%
import plotly.express as px
fig = px.scatter(abc, x="total_bill",y="tip",size="size",color="time",hover_name="day",size_max=26)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1632/4046842965.py in <module>
# ----> 1 import plotly.express as px
#       2 fig = px.scatter(abc, x="total_bill",y="tip",size="size",color="time",hover_name="day",size_max=26)
#       3 fig.show()
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# # Advanced Plot

# %%
import seaborn as sns
sns.set(style="white",color_codes=True)

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Joint Plot

# %%
g = sns.jointplot(x="total_bill",y="tip",data=tips)
g

# %%
g=sns.jointplot("total_bill","tip",data=tips,kind="reg")
# Out:
# C:\Users\Digambar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
g=sns.pairplot(data=tips)

# %% [markdown]
# # Pair Plot

# %%
iris=sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.species.value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
g=sns.pairplot(iris)

# %%
g=sns.pairplot(iris,hue="species")

# %%
g=sns.pairplot(iris,hue="species",palette="prism_r")

# %%
ax = sns.distplot(iris.sepal_length)
# Out:
# C:\Users\Digambar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # volin Plot

# %%
ax = sns.violinplot(x=tips["total_bill"])

# %%
ax = sns.violinplot(x="day",y="total_bill",hue="smoker",data=tips, palette="hot_r")

# %% [markdown]
# # Strip plot

# %%
ax = sns.stripplot(x="day", y="total_bill", data=tips)

# %% [markdown]
# # Swarm Plot

# %%
ax = sns.swarmplot(x="day", y="total_bill", data=tips)
